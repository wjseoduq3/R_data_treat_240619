# %%
# 경고 비표시
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %% [markdown]
# #### 결측치 처리

# %%
air = pd.read_csv("D:/JDY_folder/jupyter_ws/databank/20240619_nan.csv")
air
# Out:
#       MMDDHH  PM10  PM25     O3    NO2   CO    SO2
# 0   06-01-01  28.0  18.0  0.039  0.009  0.3  0.002
# 1   06-01-02  19.0  14.0  0.041  0.007  0.3  0.002
# 2   06-01-03  15.0  13.0  0.043  0.006  0.3  0.002
# 3   06-01-04  16.0  13.0  0.042  0.006  0.3  0.002
# 4   06-01-05  14.0  11.0  0.041  0.008  0.3  0.003
# 5   06-01-06  14.0  10.0  0.040  0.009  0.3  0.003
# 6   06-01-07  15.0  10.0  0.038  0.014  0.3  0.002
# 7   06-01-08  20.0  10.0  0.034  0.019  0.3  0.002
# 8   06-01-09  28.0  15.0  0.032  0.022  0.4  0.003
# 9   06-01-10  28.0  12.0  0.035  0.017  0.4  0.003
# 10  06-01-11  29.0   9.0  0.038  0.015  0.4  0.003
# 11  06-01-12  32.0  11.0  0.039  0.012  0.3  0.003
# 12  06-01-13  32.0  11.0  0.038  0.015  0.3  0.003
# 13  06-01-14   NaN   NaN    NaN    NaN  NaN    NaN
# 14  06-01-15   NaN   NaN    NaN    NaN  NaN    NaN
# 15  06-01-16   NaN   NaN  0.038  0.020  0.4  0.003
# 16  06-01-17  27.0  12.0  0.041  0.022  0.4  0.003
# ...

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MMDDHH  24 non-null     object
#  1   PM10    21 non-null     float64
#  2   PM25    21 non-null     float64
#  3   O3      22 non-null     float64
#  4   NO2     22 non-null     float64
#  5   CO      22 non-null     float64
#  6   SO2     22 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.4+ KB

# %%
air.describe()
# Out:
#             PM10       PM25         O3        NO2         CO        SO2
# count  21.000000  21.000000  22.000000  22.000000  22.000000  22.000000
# mean   23.761905  12.666667   0.039773   0.015364   0.350000   0.002727
# std     6.015852   2.198484   0.005209   0.006020   0.051177   0.000456
# min    14.000000   9.000000   0.028000   0.006000   0.300000   0.002000
# 25%    19.000000  11.000000   0.038000   0.009750   0.300000   0.002250
# 50%    25.000000  13.000000   0.039500   0.015500   0.350000   0.003000
# 75%    28.000000  14.000000   0.042750   0.020000   0.400000   0.003000
# max    32.000000  18.000000   0.049000   0.027000   0.400000   0.003000

# %%
air.isnull()
# Out:
#     MMDDHH   PM10   PM25     O3    NO2     CO    SO2
# 0    False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False
# 12   False  False  False  False  False  False  False
# 13   False   True   True   True   True   True   True
# 14   False   True   True   True   True   True   True
# 15   False   True   True  False  False  False  False
# 16   False  False  False  False  False  False  False
# ...

# %%
air.isnull().sum()
# Out:
# MMDDHH    0
# PM10      3
# PM25      3
# O3        2
# NO2       2
# CO        2
# SO2       2
# dtype: int64

# %%
#### 결측치 행 제거

# %%
air_d = air.dropna(axis=0)
air_d
# Out:
#       MMDDHH  PM10  PM25     O3    NO2   CO    SO2
# 0   06-01-01  28.0  18.0  0.039  0.009  0.3  0.002
# 1   06-01-02  19.0  14.0  0.041  0.007  0.3  0.002
# 2   06-01-03  15.0  13.0  0.043  0.006  0.3  0.002
# 3   06-01-04  16.0  13.0  0.042  0.006  0.3  0.002
# 4   06-01-05  14.0  11.0  0.041  0.008  0.3  0.003
# 5   06-01-06  14.0  10.0  0.040  0.009  0.3  0.003
# 6   06-01-07  15.0  10.0  0.038  0.014  0.3  0.002
# 7   06-01-08  20.0  10.0  0.034  0.019  0.3  0.002
# 8   06-01-09  28.0  15.0  0.032  0.022  0.4  0.003
# 9   06-01-10  28.0  12.0  0.035  0.017  0.4  0.003
# 10  06-01-11  29.0   9.0  0.038  0.015  0.4  0.003
# 11  06-01-12  32.0  11.0  0.039  0.012  0.3  0.003
# 12  06-01-13  32.0  11.0  0.038  0.015  0.3  0.003
# 16  06-01-17  27.0  12.0  0.041  0.022  0.4  0.003
# 17  06-01-18  24.0  14.0  0.048  0.016  0.4  0.003
# 18  06-01-19  25.0  12.0  0.048  0.014  0.3  0.003
# 19  06-01-20  26.0  14.0  0.043  0.020  0.4  0.003
# ...

# %% [markdown]
# #### 결측치 평균값 대체

# %%
numeric_air = air.select_dtypes(include=[int, float])
airmean = numeric_air.mean()

# %%
air_m = airmean.fillna(airmean.mean())
air_m
# Out:
# PM10    23.761905
# PM25    12.666667
# O3       0.039773
# NO2      0.015364
# CO       0.350000
# SO2      0.002727
# dtype: float64

# %%
# error occur --> airmean = air.mean()

# %%
air_dd = air.set_index('MMDDHH')
air_dd
# Out:
#           PM10  PM25     O3    NO2   CO    SO2
# MMDDHH
# 06-01-01  28.0  18.0  0.039  0.009  0.3  0.002
# 06-01-02  19.0  14.0  0.041  0.007  0.3  0.002
# 06-01-03  15.0  13.0  0.043  0.006  0.3  0.002
# 06-01-04  16.0  13.0  0.042  0.006  0.3  0.002
# 06-01-05  14.0  11.0  0.041  0.008  0.3  0.003
# 06-01-06  14.0  10.0  0.040  0.009  0.3  0.003
# 06-01-07  15.0  10.0  0.038  0.014  0.3  0.002
# 06-01-08  20.0  10.0  0.034  0.019  0.3  0.002
# 06-01-09  28.0  15.0  0.032  0.022  0.4  0.003
# 06-01-10  28.0  12.0  0.035  0.017  0.4  0.003
# 06-01-11  29.0   9.0  0.038  0.015  0.4  0.003
# 06-01-12  32.0  11.0  0.039  0.012  0.3  0.003
# 06-01-13  32.0  11.0  0.038  0.015  0.3  0.003
# 06-01-14   NaN   NaN    NaN    NaN  NaN    NaN
# 06-01-15   NaN   NaN    NaN    NaN  NaN    NaN
# 06-01-16   NaN   NaN  0.038  0.020  0.4  0.003
# 06-01-17  27.0  12.0  0.041  0.022  0.4  0.003
# 06-01-18  24.0  14.0  0.048  0.016  0.4  0.003
# 06-01-19  25.0  12.0  0.048  0.014  0.3  0.003
# ...

# %%
air_m1 = air.fillna(air_dd.mean())
air_m1
# Out:
#       MMDDHH       PM10       PM25        O3       NO2    CO       SO2
# 0   06-01-01  28.000000  18.000000  0.039000  0.009000  0.30  0.002000
# 1   06-01-02  19.000000  14.000000  0.041000  0.007000  0.30  0.002000
# 2   06-01-03  15.000000  13.000000  0.043000  0.006000  0.30  0.002000
# 3   06-01-04  16.000000  13.000000  0.042000  0.006000  0.30  0.002000
# 4   06-01-05  14.000000  11.000000  0.041000  0.008000  0.30  0.003000
# 5   06-01-06  14.000000  10.000000  0.040000  0.009000  0.30  0.003000
# 6   06-01-07  15.000000  10.000000  0.038000  0.014000  0.30  0.002000
# 7   06-01-08  20.000000  10.000000  0.034000  0.019000  0.30  0.002000
# 8   06-01-09  28.000000  15.000000  0.032000  0.022000  0.40  0.003000
# 9   06-01-10  28.000000  12.000000  0.035000  0.017000  0.40  0.003000
# 10  06-01-11  29.000000   9.000000  0.038000  0.015000  0.40  0.003000
# 11  06-01-12  32.000000  11.000000  0.039000  0.012000  0.30  0.003000
# ...

# %%
air_dd_m
# Out:
#                PM10       PM25        O3       NO2    CO       SO2
# MMDDHH
# 06-01-01  28.000000  18.000000  0.039000  0.009000  0.30  0.002000
# 06-01-02  19.000000  14.000000  0.041000  0.007000  0.30  0.002000
# 06-01-03  15.000000  13.000000  0.043000  0.006000  0.30  0.002000
# 06-01-04  16.000000  13.000000  0.042000  0.006000  0.30  0.002000
# 06-01-05  14.000000  11.000000  0.041000  0.008000  0.30  0.003000
# 06-01-06  14.000000  10.000000  0.040000  0.009000  0.30  0.003000
# 06-01-07  15.000000  10.000000  0.038000  0.014000  0.30  0.002000
# 06-01-08  20.000000  10.000000  0.034000  0.019000  0.30  0.002000
# 06-01-09  28.000000  15.000000  0.032000  0.022000  0.40  0.003000
# 06-01-10  28.000000  12.000000  0.035000  0.017000  0.40  0.003000
# 06-01-11  29.000000   9.000000  0.038000  0.015000  0.40  0.003000
# 06-01-12  32.000000  11.000000  0.039000  0.012000  0.30  0.003000
# 06-01-13  32.000000  11.000000  0.038000  0.015000  0.30  0.003000
# ...
